# %% [markdown]
# ***My first program***

# %% [markdown]
# ***Data types***

# %% [markdown]
# ***Text data type:***

# %%
name ="lavanya"
print(type(name))
# Out:
# <class 'str'>

# %% [markdown]
# **Numeric data type:**

# %%
num1=24
num2=3.34
num3=4j
print(type(num1))
print(type(num2))
print(type(num3))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %% [markdown]
# **Sequence data type:**

# %% [markdown]
# **lists:**

# %%
lis=['lav','123','30.24']
type(lis)
# Out:
# list

# %%
print(lis)
# Out:
# ['lav', '123', '30.24']

# %%
lis2=['apple','123','india']
print(len(lis))
print(len(lis2))
lis3=lis+lis2
print(lis3)
print(len(lis3))
# Out:
# 3
# 3
# ['lav', '123', '30.24', 'apple', '123', 'india']
# 6

# %%
lis2.append('hubli')

# %%
lis2
# Out:
# ['apple', '123', 'india', 'hubli']

# %%
lis2.clear()

# %%
lis2
# Out:
# []

# %%
lis=['ll','bvb','kle']
lis[0]
# Out:
# 'll'

# %%
lis.sort()

# %%
lis
# Out:
# ['bvb', 'kle', 'll']

# %% [markdown]
# **Tuple**

# %%
tuple1=("dharwad","hubli")
print(type(tuple1))
tuple2=("hubli")
print(type(tuple2))
tuple3=(1,2,3,4,5)
print(type(tuple3))
tuple4=tuple((1,2,3,4,5))
print(type(tuple4))
# Out:
# <class 'tuple'>
# <class 'str'>
# <class 'tuple'>
# <class 'tuple'>

# %%
tuple1=("hubli","kle","bvb")
print(tuple1[0])
print(tuple1[2])
print(tuple1[-1])
print(tuple1[1])
tuple2=tuple1+tuple1
print(tuple2)
tuple3=tuple2*2
print(tuple3)
y=tuple3.index('kle')
print(y)

x=tuple3.count('kle')
print(x)
# Out:
# hubli
# bvb
# bvb
# kle
# ('hubli', 'kle', 'bvb', 'hubli', 'kle', 'bvb')
# ('hubli', 'kle', 'bvb', 'hubli', 'kle', 'bvb', 'hubli', 'kle', 'bvb', 'hubli', 'kle', 'bvb')
# 1
# 4

# %%
x=("hubli","bvb","corag")
print(type(x))
# Out:
# <class 'tuple'>

# %%
y=list(x)
y[2]="mysore"
x=tuple(y)
print(x)
# Out:
# ('hubli', 'bvb', 'mysore')

# %% [markdown]
# ***Sets***

# %%
set1={"blue","pink","red","pink"}
print(set1)
set1.add('orange')
print(set1)
set2={"baloon","net","ball"}
set1.update(set2)
print(set1)
# Out:
# {'pink', 'blue', 'red'}
# {'pink', 'blue', 'orange', 'red'}
# {'blue', 'orange', 'red', 'pink', 'net', 'ball', 'baloon'}

# %% [markdown]
# ***Dictionary:***

# %%
Dict1={"Name":"lavanya",
       "Div":"A"}
print(Dict1)
# Out:
# {'Name': 'lavanya', 'Div': 'A'}

# %%
dict2=dict(fruit="pineapple",dessert="icecream")
print(dict2)
print(type(dict2))
# Out:
# {'fruit': 'pineapple', 'dessert': 'icecream'}
# <class 'dict'>

# %% [markdown]
# ***Coditional sta:***

# %%
a=input("enter the number a")
b=input("enter the number b")
print(a)
print(b)
# Out:
# enter the number a2
# enter the number b4
# 2
# 4

# %%
if a>b:
  print("value is greater than b")
else:
  print("hello")
# Out:
# hello

# %%
ball1_clr="G"
ball2_clr="B"
ball3_clr="R"
ball4_clr="W"
pick_ball=input("pick a ball")
if pick_ball==ball1_clr:
    print("green ball")
elif pick_ball==ball2_clr:
    print("blue ball")
elif pick_ball==ball3_clr:
      print("red ball")
else:
      print("white ball")
# Out:
# pick a ballR
# red ball

# %% [markdown]
# ***OPREATORS***

# %%
age=int(input("Enter the age"))
print(age>22 and age<60)
# Out:
# Enter the age23
# True

# %% [markdown]
# ***ASSIGNMENT:***

# %%
lis=['123','3024']
type(lis)

print(lis)
# Out:
# ['123', '3024']

# %%
lis2=['engineering','324']
print(len(lis))
print(len(lis2))
lis3=lis+lis2
print(lis3)
print(len(lis3))
# Out:
# 2
# 2
# ['123', '3024', 'engineering', '324']
# 4

# %%
lis3.append ('college')
lis3
# Out:
# ['123', '3024', 'engineering', '324', 'college', 'college']

# %% [markdown]
# ***tuples***

# %%
tuple=("tech","non tech","bvb")
print(tuple[1])
print(tuple[0])
print(tuple[-1])
tuple[1]
tuple[0]
tuple[-1]
# Out:
# non tech
# tech
# bvb
# 'bvb'

# %% [markdown]
# ***sets***

# %%
set1={"one","two","three"}
print(set1)
# Out:
# {'one', 'two', 'three'}

# %%
set1.add('zero')
print(set1)
# Out:
# {'one', 'two', 'zero', 'three'}

# %% [markdown]
# **Dictionay:**

# %%
Dict1={"stu name":"lavanya",
       "usn no":"...415"}
print(Dict1)
# Out:
# {'stu name': 'lavanya', 'usn no': '...415'}

# %% [markdown]
# **conditional sta:**

# %%
a=int(input("Enter a value:"))
print(a)
# Out:
# Enter a value:246
# 246

# %%
if((a%2)==0):
 print("number is even")
else:
 print("number is odd")
# Out:
# number is even

# %% [markdown]
# ***operators:***

# %%
x=12
y=8
mod=x%y
power=x**y-x/y
print(mod)
print(power)
# Out:
# 4
# 429981694.5

# %%
x=20
y=30
z=40
if x>y and y>z:
  print("x is greater the y")
else:
    print("x is lesser than y")
# Out:
# x is lesser than y
